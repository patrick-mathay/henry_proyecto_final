# %%
import pandas as pd

# %%
fl_restuarants2021 = 'CBP2021.CB2100CBP-2024-05-10T030649.csv'

df_fl2021= pd.read_csv(fl_restuarants2021)

df_fl2021
# Out:
#    Geographic Area Name (NAME)  2017 NAICS code (NAICS2017)  \
# 0                      Florida                       722511
# 1                      Florida                       722511
# 2                      Florida                       722511
# 3                      Florida                       722511
# 4                      Florida                       722511
# 5                      Florida                       722511
# 6                      Florida                       722511
# 7                      Florida                       722511
# 8                      Florida                       722511
# 9                      Florida                       722511
# 10                     Florida                       722511
# 11                     Florida                       722511
# 12                     Florida                       722511
# 13                     Florida                       722511
# 14                     Florida                       722511
# ...

# %%
fl_restuarants2020 = 'CBP2020.CB2000CBP-2024-05-10T032217.csv'

df_fl2020= pd.read_csv(fl_restuarants2020)

df_fl2020
# Out:
#    Geographic Area Name (NAME)  2017 NAICS code (NAICS2017)  \
# 0                      Florida                       722511
# 1                      Florida                       722511
# 2                      Florida                       722511
# 3                      Florida                       722511
# 4                      Florida                       722511
# 5                      Florida                       722511
# 6                      Florida                       722511
# 7                      Florida                       722511
# 8                      Florida                       722511
# 9                      Florida                       722511
# 10                     Florida                       722511
# 11                     Florida                       722511
# 12                     Florida                       722511
# 13                     Florida                       722511
# 14                     Florida                       722511
# ...

# %%
fl_restuarants2019 = 'CBP2019.CB1900CBP-2024-05-10T032249.csv'

df_fl2019 = pd.read_csv(fl_restuarants2019)

df_fl2019
# Out:
#    Geographic Area Name (NAME)  2017 NAICS code (NAICS2017)  \
# 0                      Florida                       722511
# 1                      Florida                       722511
# 2                      Florida                       722511
# 3                      Florida                       722511
# 4                      Florida                       722511
# 5                      Florida                       722511
# 6                      Florida                       722511
# 7                      Florida                       722511
# 8                      Florida                       722511
# 9                      Florida                       722511
# 10                     Florida                       722511
# 11                     Florida                       722511
# 12                     Florida                       722511
# 13                     Florida                       722511
# 14                     Florida                       722511
# ...

# %%
df_2019_2021 = pd.concat([df_fl2019, df_fl2020, df_fl2021], ignore_index=True)

print(df_2019_2021)
# Out:
#     Geographic Area Name (NAME)  2017 NAICS code (NAICS2017)  \
# 0                       Florida                       722511
# 1                       Florida                       722511
# 2                       Florida                       722511
# 3                       Florida                       722511
# 4                       Florida                       722511
# ..                          ...                          ...
# 128                     Florida                       722511
# 129                     Florida                       722511
# 130                     Florida                       722511
# 131                     Florida                       722511
# 132                     Florida                       722511
#
#     Meaning of NAICS code (NAICS2017_LABEL)  \
# 0                  Full-service restaurants
# 1                  Full-service restaurants
# 2                  Full-service restaurants
# 3                  Full-service restaurants
# ...
